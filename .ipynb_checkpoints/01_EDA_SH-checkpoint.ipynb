# %% [markdown]
# # 데이터 로드

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings(action='ignore')

# 폰트깨짐 해결하기
## unicode minus를 사용하지 않기 위한 설정 (minus 깨짐현상 방지)
plt.rcParams['axes.unicode_minus'] = False
## 나눔고딕 설정
plt.rcParams['font.family'] = 'NanumGothic'
## 폰트 크기 조절
plt.rcParams['font.size'] = 23

from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')


pd.options.display.max_rows=100
pd.options.display.max_columns=100
# pd.set_option(‘display.float_format’,‘{:.4f}’.format)

# %%
df = pd.read_csv('./data/rawdata.csv', index_col=0)
df = raw_df.drop(df.columns[0], axis=1)
df
# Out:
#                                          name  num_faved        pid    price  \
# 0    (가격내림)나이키 덩크 하이 레트로 챔피언쉽 네이비 265사이즈 팔아요.          3  169499712   190000
# 1                 [260] 나이키 덩크하이 레트로 챔피언쉽 네이비          0  169629181   220000
# 2                   나이키 덩크하이 레트로 챞피언쉽 네이비 260          3  169097255   160000
# 3                       나이키 덩크하이 챔피언쉽 네이비 260          3  169073677   160000
# 4                           나이키 덩크 하이 네이비 265          1  168877311   270000
# ..                                        ...        ...        ...      ...
# 513                   트레비스스캇 조던 1 로우 300 교환환영          0  161679574  2500000
# 514                 나이키 프라그먼트트레비스스캇 조던1 로우270          1  161671344  1750000
# 515  조던1 트레비스캇 프라그먼트 레트로 로우 OG sp 밀리터리 블루 260          0  161671038  1800000
# 516                       에어 조던 로우1 트레비스캇 275          0  161653518  1900000
# 517                         조던1로우 260 트레비스 스캇          0  161653134  1800000
#
#      status       uid  update_time  used             datetime        date  \
# 0         0  10473233   1636628281     2  2021-11-11 19:58:01  2021-11-11
# 1         0   8587620   1636627849     2  2021-11-11 19:50:49  2021-11-11
# 2         0  76575156   1636624615     1  2021-11-11 18:56:55  2021-11-11
# 3         0  76575156   1636624609     1  2021-11-11 18:56:49  2021-11-11
# 4         0   2312006   1636616082     1  2021-11-11 16:34:42  2021-11-11
# ..      ...       ...          ...   ...                  ...         ...
# 513       3   7326303   1628846739     1  2021-08-13 18:25:39  2021-08-13
# 514       3  11927253   1628841393     1  2021-08-13 16:56:33  2021-08-13
# 515       3  12558916   1628841203     1  2021-08-13 16:53:23  2021-08-13
# 516       3   7508376   1628829952     1  2021-08-13 13:45:52  2021-08-13
# 517       3   6165763   1628829698     1  2021-08-13 13:41:38  2021-08-13
#
#         product_name brand product_type    color  size  release_price  \
# 0       나이키 덩크하이 네이비   나이키     나이키 덩크하이      네이비   265       129000.0
# 1       나이키 덩크하이 네이비   나이키     나이키 덩크하이      네이비   260       129000.0
# 2       나이키 덩크하이 네이비   나이키     나이키 덩크하이      네이비   260       129000.0
# 3       나이키 덩크하이 네이비   나이키     나이키 덩크하이      네이비   260       129000.0
# 4       나이키 덩크하이 네이비   나이키     나이키 덩크하이      네이비   265       129000.0
# ..               ...   ...          ...      ...   ...            ...
# 513  조던 1 로우 트레비스 스캇    조던      조던 1 로우  트레비스 스캇   300       189000.0
# 514  조던 1 로우 트레비스 스캇    조던      조던 1 로우  트레비스 스캇   270       189000.0
# 515  조던 1 로우 트레비스 스캇    조던      조던 1 로우  트레비스 스캇   260       189000.0
# 516  조던 1 로우 트레비스 스캇    조던      조던 1 로우  트레비스 스캇   275       189000.0
# 517  조던 1 로우 트레비스 스캇    조던      조던 1 로우  트레비스 스캇   260       189000.0
#
#     location1 location2  location3
# 0       인천광역시       남동구      장수서창동
# 1       서울특별시       금천구      독산제3동
# 2       인천광역시       부평구       부평3동
# 3       인천광역시       부평구       부평3동
# 4        경상남도       김해시        북부동
# ..        ...       ...        ...
# 513     서울특별시      영등포구      영등포본동
# 514       NUL       NUL        NaN
# 515       경기도       고양시  일산서구 일산2동
# 516       강원도       양구군        양구읍
# 517      전라남도       여수시        여서동
#
# [7621 rows x 19 columns]

# %%
df[df['date'] < '2020-11-01']
# Out:
#                             name  num_faved        pid   price  status  \
# 1008          뉴발란스992 화이트 실버 260          2  126828343  400000       3
# 4401  [250] 뉴발란스 992 오리지날 그레이 맨즈          2   58655093   68000       3
# 6358  [250] 뉴발란스 992 오리지날 그레이 맨즈          2   58655093   68000       3
#
#           uid  update_time  used             datetime        date  \
# 1008  8671319   1601970397     2  2020-10-06 16:46:37  2020-10-06
# 4401  1379306   1481413623    13  2016-12-11 08:47:03  2016-12-11
# 6358  1379306   1481413623    13  2016-12-11 08:47:03  2016-12-11
#
#         product_name brand product_type  color  size  release_price location1  \
# 1008  뉴발란스 992 화이트실버  뉴발란스     뉴발란스 992  화이트실버   260       259000.0     서울특별시
# 4401    뉴발란스 992 그레이  뉴발란스     뉴발란스 992    그레이   250       259000.0        흑석
# 6358    뉴발란스 992 그레이  뉴발란스     뉴발란스 992    그레이   250       259000.0        흑석
#
#      location2 location3
# 1008      서대문구     홍제제1동
# 4401        흑석       흑석역
# 6358        흑석       흑석역

# %%
# 스타피쉬 발매가 추가 -> 1차 raw 파일
df['release_price'] = df['release_price'].fillna('159000')
df[df['color'] == '스타피쉬']

# int 값 변환
df['release_price'] = df['release_price'].astype('int', errors='ignore')
df['release_price']
# Out:
# 0       129000
# 1       129000
# 2       129000
# 3       129000
# 4       129000
#          ...
# 7616    189000
# 7617    189000
# 7618    189000
# 7619    189000
# 7620    189000
# Name: release_price, Length: 7621, dtype: int32

# %%
# date 값 조정 2020-11-01 ~ 현재
# df.loc(df.date < '2020-11-01')
idx1 = df[df['date'] < '2020-11-01'].index
df = df.drop(idx1)

# %%
# index datetime으로 변경 (최신 등록순)
df.set_index('datetime', inplace=True)
df
# Out:
#                               location  \
# datetime
# 2021-11-11 19:58:01    인천광역시 남동구 장수서창동
# 2021-11-11 19:50:49    서울특별시 금천구 독산제3동
# 2021-11-11 18:56:55     인천광역시 부평구 부평3동
# 2021-11-11 18:56:49     인천광역시 부평구 부평3동
# 2021-11-11 16:34:42       경상남도 김해시 북부동
# ...                                ...
# 2021-08-13 18:25:39   서울특별시 영등포구 영등포본동
# 2021-08-13 16:56:33                NaN
# 2021-08-13 16:53:23  경기도 고양시 일산서구 일산2동
# 2021-08-13 13:45:52        강원도 양구군 양구읍
# 2021-08-13 13:41:38       전라남도 여수시 여서동
#
#                                                          name  num_faved  \
# datetime
# 2021-11-11 19:58:01  (가격내림)나이키 덩크 하이 레트로 챔피언쉽 네이비 265사이즈 팔아요.          3
# 2021-11-11 19:50:49               [260] 나이키 덩크하이 레트로 챔피언쉽 네이비          0
# 2021-11-11 18:56:55                 나이키 덩크하이 레트로 챞피언쉽 네이비 260          3
조던 1 로우 트레비스 스캇    조던      조던 1 로우  트레비스 스캇   275
# 2021-08-13 13:41:38  조던 1 로우 트레비스 스캇    조던      조던 1 로우  트레비스 스캇   260
#
#                      release_price location1 location2  location3
# datetime
# 2021-11-11 19:58:01         129000     인천광역시       남동구      장수서창동
# 2021-11-11 19:50:49         129000     서울특별시       금천구      독산제3동
# 2021-11-11 18:56:55         129000     인천광역시       부평구       부평3동
# 2021-11-11 18:56:49         129000     인천광역시       부평구       부평3동
# 2021-11-11 16:34:42         129000      경상남도       김해시        북부동
# ...                            ...       ...       ...        ...
# 2021-08-13 18:25:39         189000     서울특별시      영등포구      영등포본동
# 2021-08-13 16:56:33         189000       NUL       NUL        NaN
# 2021-08-13 16:53:23         189000       경기도       고양시  일산서구 일산2동
# 2021-08-13 13:45:52         189000       강원도       양구군        양구읍
# 2021-08-13 13:41:38         189000      전라남도       여수시        여서동
#
# [7618 rows x 18 columns]

# %%
# 컬럼 순서 보기좋게 정렬
df = df[["pid", "uid", "brand","product_name",  "product_type", "color" , "size" ,"price",  "release_price", "date", "location1" ,"location2","status","used", "name"]]

# %%
df
# Out:
#                            pid       uid brand     product_name product_type  \
# datetime
# 2021-11-11 19:58:01  169499712  10473233   나이키     나이키 덩크하이 네이비     나이키 덩크하이
# 2021-11-11 19:50:49  169629181   8587620   나이키     나이키 덩크하이 네이비     나이키 덩크하이
# 2021-11-11 18:56:55  169097255  76575156   나이키     나이키 덩크하이 네이비     나이키 덩크하이
# 2021-11-11 18:56:49  169073677  76575156   나이키     나이키 덩크하이 네이비     나이키 덩크하이
# 2021-11-11 16:34:42  168877311   2312006   나이키     나이키 덩크하이 네이비     나이키 덩크하이
# ...                        ...       ...   ...              ...          ...
# 2021-08-13 18:25:39  161679574   7326303    조던  조던 1 로우 트레비스 스캇      조던 1 로우
# 2021-08-13 16:56:33  161671344  11927253    조던  조던 1 로우 트레비스 스캇      조던 1 로우
# 2021-08-13 16:53:23  161671038  12558916    조던  조던 1 로우 트레비스 스캇      조던 1 로우
# 2021-08-13 13:45:52  161653518   7508376    조던  조던 1 로우 트레비스 스캇      조던 1 로우
# 2021-08-13 13:41:38  161653134   6165763    조던  조던 1 로우 트레비스 스캇      조던 1 로우
#
#                        color  size    price  release_price        date  \
# datetime
# 2021-11-11 19:58:01      네이비   265   190000         129000  2021-11-11
# 2021-11-11 19:50:49      네이비   260   220000         129000  2021-11-11
# 2021-11-11 18:56:55      네이비   260   160000         129000  2021-11-11
# 2021-11-11 18:56:49      네이비   260   160000         129000  2021-11-11
# 2021-11-11 16:34:42      네이비   265   270000         129000  2021-11-11
# ...                      ...   ...      ...            ...         ...
# 2021-08-13 18:25:39  트레비스 스캇   300  2500000         189000  2021-08-13
# 2021-08-13 16:56:33  트레비스 스캇   270  1750000         189000  2021-08-13
# 2021-08-13 16:53:23  트레비스 스캇   260  1800000         189000  2021-08-13
# 2021-08-13 13:45:52  트레비스 스캇   275  1900000         189000  2021-08-13
# 2021-08-13 13:41:38  트레비스 스캇   260  1800000         189000  2021-08-13
#
#                     location1 location2  status  used  \
# datetime
# 2021-11-11 19:58:01     인천광역시       남동구       0     2
# 2021-11-11 19:50:49     서울특별시       금천구       0     2
# 2021-11-11 18:56:55     인천광역시       부평구       0     1
# 2021-11-11 18:56:49     인천광역시       부평구       0     1
# 2021-11-11 16:34:42      경상남도       김해시       0     1
# ...                       ...       ...     ...   ...
# 2021-08-13 18:25:39     서울특별시      영등포구       3     1
# 2021-08-13 16:56:33       NUL       NUL       3     1
# 2021-08-13 16:53:23       경기도       고양시       3     1
# 2021-08-13 13:45:52       강원도       양구군       3     1
# 2021-08-13 13:41:38      전라남도       여수시       3     1
#
#                                                          name
# datetime
# 2021-11-11 19:58:01  (가격내림)나이키 덩크 하이 레트로 챔피언쉽 네이비 265사이즈 팔아요.
# 2021-11-11 19:50:49               [260] 나이키 덩크하이 레트로 챔피언쉽 네이비
# 2021-11-11 18:56:55                 나이키 덩크하이 레트로 챞피언쉽 네이비 260
# 2021-11-11 18:56:49                     나이키 덩크하이 챔피언쉽 네이비 260
# 2021-11-11 16:34:42                         나이키 덩크 하이 네이비 265
# ...                                                       ...
# 2021-08-13 18:25:39                   트레비스스캇 조던 1 로우 300 교환환영
# 2021-08-13 16:56:33                 나이키 프라그먼트트레비스스캇 조던1 로우270
# 2021-08-13 16:53:23  조던1 트레비스캇 프라그먼트 레트로 로우 OG sp 밀리터리 블루 260
# 2021-08-13 13:45:52                       에어 조던 로우1 트레비스캇 275
# 2021-08-13 13:41:38                         조던1로우 260 트레비스 스캇
#
# [7618 rows x 15 columns]

# %%
# 가격 이상치 정제
# 함수로 만들어서 boolean 적용
# 1000으로 나누어떨어지지 않는 Price는 비정상적인 가격
# 10000보다 낮은 가격은 비정상적인 가격
# 5000000보다 높은 가격은 비정상적인 가격
def make_bool(x):
    if x % 1000 != 0:
        return True
    elif x < 10000:
        return True
    elif x > 5000000:
        return True
    else:
        return False
data[‘abnormal_price’] = data[‘price’].apply(make_bool)

# %% [markdown]
# # Seaborn as sns
# ### 컬럼
# - location 판매지역
#     -- location1 도,광역시
#     -- location2 시군구
#     -- location3 동읍면
#
# - name 게시제목
#     -- product_name 공식제품명
#     -- brand 브랜드 (나이키, 뉴발 등)
#     -- product_type 제품 라인 (뉴발 992 등)
#     -- color 색깔 (스타피쉬 등)
#     -- pid 게시글코드
#     -- size 사이즈
#
# - update_time 업뎃 시간
#
# - status (0 = 판매중 / 1 = 예약완료 / 3 = 판매완료) : 상품 판매 상태
#
# - used (1 = 중고 / 2 = 새상품 / 13 = 중고) : 상품상태
#
# - uid 유저아이디
#
# - release_price 정발가
#
# - num_faved 종아요(즐찾)수
#
# --------

# %%
plt.rcParams['axes.unicode_minus'] = False
sns.set(font_scale = 1)  
plt.style.use(['fivethirtyeight'])
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 제품별 리셀 가격 추이 -> histplot
# - filter = pname
# - x = datetime
# - y = price
#
#
# df.groupby("product_name")["price"].median().sort_values(ascending = False) , df.groupby("product_name")["release_price"].median().sort_values(ascending = False)

# %% [markdown]
# ## 가장 많이 올라오는 color

# %%
df = pd.read_csv('./data/bunjang/rawdata_Final.csv', index_col=0)
df.head()
# Out:
#          pid       uid brand  product_name product_type color  size   price  \
# 0  169499712  10473233   나이키  나이키 덩크하이 네이비     나이키 덩크하이   네이비   265  190000
# 1  169629181   8587620   나이키  나이키 덩크하이 네이비     나이키 덩크하이   네이비   260  220000
# 2  169097255  76575156   나이키  나이키 덩크하이 네이비     나이키 덩크하이   네이비   260  160000
# 3  169073677  76575156   나이키  나이키 덩크하이 네이비     나이키 덩크하이   네이비   260  160000
# 4  168877311   2312006   나이키  나이키 덩크하이 네이비     나이키 덩크하이   네이비   265  270000
#
#    release_price             datetime        date location1 location2  status  \
# 0         129000  2021-11-11 19:58:01  2021-11-11     인천광역시       남동구       0
# 1         129000  2021-11-11 19:50:49  2021-11-11     서울특별시       금천구       0
# 2         129000  2021-11-11 18:56:55  2021-11-11     인천광역시       부평구       0
# 3         129000  2021-11-11 18:56:49  2021-11-11     인천광역시       부평구       0
# 4         129000  2021-11-11 16:34:42  2021-11-11      경상남도       김해시       0
#
#    used                                      name
# 0     2  (가격내림)나이키 덩크 하이 레트로 챔피언쉽 네이비 265사이즈 팔아요.
# 1     2               [260] 나이키 덩크하이 레트로 챔피언쉽 네이비
# 2     1                 나이키 덩크하이 레트로 챞피언쉽 네이비 260
# 3     1                     나이키 덩크하이 챔피언쉽 네이비 260
# 4     1                         나이키 덩크 하이 네이비 265

# %%
plt.figure(figsize = (15,10))
plt.rc('font', size=15)
plt.xticks(rotation=90)
plt.bar(df['product_name'].value_counts().index, df['product_name'].value_counts().values )
plt.show()

# %% [markdown]
# ## 지역별(location1)로 가장 많이 올라온 제품(counts)

# %%
# 한글폰트
# from matplotlib import font_manager, rc
# f_path = "c:/Windows/Fonts/malgun.ttf"
# font_name = font_manager.FontProperties(fname=f_path).get_name()
# rc('font', family=font_name)

# 폰트깨짐 해결하기
## unicode minus를 사용하지 않기 위한 설정 (minus 깨짐현상 방지)
plt.rcParams['axes.unicode_minus'] = False
## 나눔고딕 설정
plt.rcParams['font.family'] = 'NanumGothic'
## 폰트 크기 조절
plt.rcParams['font.size'] = 23

# %%
df[df['location1'] == '서울특별시']['location2']
loc_brand = df.loc[:,['brand', 'location2']]
loc_brand
# Out:
#      brand location2
# 0      나이키       남동구
# 1      나이키       금천구
# 2      나이키       부평구
# 3      나이키       부평구
# 4      나이키       김해시
# ...    ...       ...
# 7616    조던      영등포구
# 7617    조던       NUL
# 7618    조던       고양시
# 7619    조던       양구군
# 7620    조던       여수시
#
# [7621 rows x 2 columns]

# %% [markdown]
# ## Heatmap
# 제품 간 가격 상관관계

# %%
df['datetime'].values[0]
# Out:
# '2021-11-11 19:58:01'
