# %% [markdown]
# # 뉴발란스 992 EDA

# %% [markdown]
# ### import package

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings(action='ignore') # 빨간색 경고메시지 무시해줌

import matplotlib
matplotlib.rc('font', family='AppleGothic') # Mac OS 한글깨짐 방지
matplotlib.rc('axes', unicode_minus=False)

from IPython.display import set_matplotlib_formats # 선명한 그래프
set_matplotlib_formats('retina')

# 데이터프레임이 짤려보이는 것을 해결해줌
pd.options.display.max_rows=100
pd.options.display.max_columns=100
# pd.set_option('display.float_format','{:.4f}'.format) # 숫자포맷설정

# %% [markdown]
# ### Data Load

# %%
newbal = pd.read_csv('./data/newbalance_992.csv')

# %%
newbal = newbal.drop(newbal.columns[0], axis=1)

# %% [markdown]
# ### EDA

# %%
newbal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2846 entries, 0 to 2845
# Data columns (total 41 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ad                      2846 non-null   bool
#  1   bizseller               2846 non-null   bool
#  2   checkout                2846 non-null   bool
#  3   contact_hope            2846 non-null   bool
#  4   free_shipping           2846 non-null   bool
#  5   is_adult                2846 non-null   bool
#  6   is_super_up_shop        0 non-null      float64
#  7   location                2469 non-null   object
#  8   max_cpc                 0 non-null      float64
#  9   name                    2846 non-null   object
#  10  num_comment             2846 non-null   int64
#  11  num_faved               2846 non-null   int64
#  12  only_neighborhood       2846 non-null   bool
#  13  outlink_url             0 non-null      float64
#  14  pid                     2846 non-null   int64
#  15  price                   2846 non-null   int64
#  16  product_image           2846 non-null   object
#  17  pu_id                   0 non-null      float64
#  18  ref_campaign            0 non-null      float64
#  19  ref_code                2846 non-null   object
#  20  ref_medium              0 non-null      float64
#  21  ref_content             0 non-null      float64
#  22  ref_source              0 non-null      float64
#  23  status                  2846 non-null   int64
#  24  style                   0 non-null      float64
#  25  super_up                0 non-null      float64
#  26  tag                     2684 non-null   object
#  27  uid                     2846 non-null   int64
#  28  update_time             2846 non-null   int64
#  29  used                    2846 non-null   int64
#  30  bun_pay_filter_enabled  2846 non-null   bool
#  31  imp_id                  2846 non-null   object
#  32  ad_ref                  0 non-null      float64
#  33  faved                   2846 non-null   bool
#  34  datetime                2846 non-null   object
#  35  year                    2846 non-null   int64
#  36  month                   2846 non-null   int64
#  37  day                     2846 non-null   int64
#  38  week                    2846 non-null   int64
#  39  weekday                 2846 non-null   int64
#  40  hour                    2846 non-null   int64
# dtypes: bool(9), float64(11), int64(14), object(7)
# memory usage: 736.6+ KB

# %%
newbal.columns
# Out:
# Index(['ad', 'bizseller', 'checkout', 'contact_hope', 'free_shipping',
#        'is_adult', 'is_super_up_shop', 'location', 'max_cpc', 'name',
#        'num_comment', 'num_faved', 'only_neighborhood', 'outlink_url', 'pid',
#        'price', 'product_image', 'pu_id', 'ref_campaign', 'ref_code',
#        'ref_medium', 'ref_content', 'ref_source', 'status', 'style',
#        'super_up', 'tag', 'uid', 'update_time', 'used',
#        'bun_pay_filter_enabled', 'imp_id', 'ad_ref', 'faved', 'datetime',
#        'year', 'month', 'day', 'week', 'weekday', 'hour'],
#       dtype='object')

# %%
columns = ['ad', 'location', 'name', 'num_comment', 'num_faved', 'price', 'status', 'uid', 'used','bun_pay_filter_enabled',
           'datetime', 'year', 'month', 'day', 'week', 'weekday', 'hour']

# %%
newbal_df = newbal[columns]

# %%
newbal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2846 entries, 0 to 2845
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ad                      2846 non-null   bool
#  1   location                2469 non-null   object
#  2   name                    2846 non-null   object
#  3   num_comment             2846 non-null   int64
#  4   num_faved               2846 non-null   int64
#  5   price                   2846 non-null   int64
#  6   status                  2846 non-null   int64
#  7   uid                     2846 non-null   int64
#  8   used                    2846 non-null   int64
#  9   bun_pay_filter_enabled  2846 non-null   bool
#  10  datetime                2846 non-null   object
#  11  year                    2846 non-null   int64
#  12  month                   2846 non-null   int64
#  13  day                     2846 non-null   int64
#  14  week                    2846 non-null   int64
#  15  weekday                 2846 non-null   int64
#  16  hour                    2846 non-null   int64
# dtypes: bool(2), int64(12), object(3)
# memory usage: 339.2+ KB

# %% [markdown]
# # 뉴발란스 992 그레이

# %% [markdown]
# ## name 컬럼

# %% [markdown]
# - 일단 정확하게 '뉴발란스 992 그레이'라고 적어놓은 제품만 추출함.
# - 인덱스는 항상 초기화 해주어야한다.

# %%
newbal_gray = newbal_df[newbal_df['name'].str.contains("뉴발란스 992 그레이")]
newbal_gray = newbal_gray.reset_index(drop=True)

# %%
newbal_gray['name']
# Out:
# 0            265) 뉴발란스 992 그레이 팝니다.
# 1      270) 뉴발란스 992 그레이 팝니다(박스구겨짐)
# 2                [280] 뉴발란스 992 그레이
# 3                  뉴발란스 992 그레이 265
# 4                [285] 뉴발란스 992 그레이
#                    ...
# 364              [235] 뉴발란스 992 그레이
# 365              [270] 뉴발란스 992 그레이
# 366              [230] 뉴발란스 992 그레이
# 367                뉴발란스 992 그레이 270
# 368                뉴발란스 992 그레이 270
# Name: name, Length: 369, dtype: object

# %% [markdown]
# #### 제품명

# %%
newbal_gray['pname'] = '뉴발란스 992 그레이'

# %% [markdown]
# **제품명에서 파생하여 brand, product_type, color 가져옴.**

# %%
newbal_gray['brand'] = '뉴발란스'

# %%
newbal_gray['product_type'] = '뉴발란스 992'

# %%
newbal_gray['color'] = '그레이'

# %% [markdown]
# #### size 처리
# - name컬럼에서 숫자만 뽑아낸뒤, 992숫자를 지운다.
# - 이상한값들이 많아서 이는 나중에 없애줘야한다.
# - 숫자로 변환해서 150~350 사이숫자만 냅두고, 나머지는 Null값으로 둔다.

# %%
import re
# name에서 숫자만 추출
number = []
for i in range(0, len(newbal_gray)):
    number.append(re.sub(r'[^0-9]','',newbal_gray['name'].values[i]))
newbal_gray["size"] = pd.DataFrame(number)

# %%
# name에서 992 제거
size = []
for i in range(0, len(newbal_gray)):
    size.append(re.sub('992','',newbal_gray['size'][i]))
newbal_gray["size"] = pd.DataFrame(size)

# %%
# 1단계
def size (x):
    return x[0:3]

# %%
newbal_gray['size'] = newbal_gray['size'].apply(size)

# %%
# # 2단계
# int 변환 후 150 ~ 350 사이값
newbal_gray['size'] = newbal_gray['size'].replace('','0')
newbal_gray['size'] = newbal_gray['size'].astype(int)
newbal_gray['size'][(newbal_gray['size'] >= 200) & (newbal_gray['size'] <= 350)].value_counts().sort_index()
# Out:
# 220     2
# 225     6
# 230     6
# 235     7
# 240     9
# 245    17
# 250    17
# 255    14
# 260    44
# 265    49
# 270    45
# 275    48
# 280    40
# 285    10
# 290    12
# 295     7
# 300     3
# 310     2
# 320     1
# Name: size, dtype: int64

# %% [markdown]
# ## price 컬럼
# - 정발가 : 259,000원
# - 뉴발란스 992 그레이 크림 거래 범위 기준 : 200,000 이상 500,000 이하
# - 이상한 값들 제거해야함

# %%
newbal_gray = newbal_gray[(newbal_gray['price'] >= 200000) & (newbal_gray['price'] <= 500000)]

# %%
newbal_gray
# Out:
#         ad           location                          name  num_comment  \
# 0    False    서울특별시 강서구 발산제1동        265) 뉴발란스 992 그레이 팝니다.            0
# 1    False    서울특별시 강서구 발산제1동  270) 뉴발란스 992 그레이 팝니다(박스구겨짐)            0
# 2    False      인천광역시 서구 청라3동            [280] 뉴발란스 992 그레이            0
# 3    False         경기도 부천시 상동              뉴발란스 992 그레이 265            0
# 4    False   경상남도 창원시 성산구 상남동            [285] 뉴발란스 992 그레이            0
# ..     ...                ...                           ...          ...
# 364  False     서울특별시 송파구 풍납2동            [235] 뉴발란스 992 그레이            0
# 365  False  경기도 고양시 일산서구 주엽2동            [270] 뉴발란스 992 그레이            0
# 366  False        경기도 군포시 금정동            [230] 뉴발란스 992 그레이            0
# 367  False   서울특별시 서대문구 홍제제2동              뉴발란스 992 그레이 270            0
# 368  False   서울특별시 서대문구 홍제제2동              뉴발란스 992 그레이 270            0
#
#      num_faved   price  status       uid  used  bun_pay_filter_enabled  \
# 0            9  410000       0   1585398     2                    True
# 1            3  390000       0   1585398     2                    True
# 2            0  380000       0   3756852     2                   False
# 3            0  400000       0  75182195     2                   False
# 4            0  345000       0   9987908     2                   False
# ..         ...     ...     ...       ...   ...                     ...
# 364          0  300000       3   5619804     2                    True
# 365          0  390000       3   2477372     2                   False
# 366          5  360000       3   7623840     2                   False
# 367          2  420000       3  12944178    13                   False
# 368          1  420000       3  12944178     2                   False
#
#                 datetime  year  month  day  week  weekday  hour         pname  \
# 0    2021-11-11 09:24:24  2021     11   11    45        3     9  뉴발란스 992 그레이
# 1    2021-11-11 09:24:24  2021     11   11    45        3     9  뉴발란스 992 그레이
# 2    2021-11-11 08:31:40  2021     11   11    45        3     8  뉴발란스 992 그레이
# 3    2021-11-11 08:04:30  2021     11   11    45        3     8  뉴발란스 992 그레이
# 4    2021-11-11 07:55:01  2021     11   11    45        3     7  뉴발란스 992 그레이
# ..                   ...   ...    ...  ...   ...      ...   ...           ...
# 364  2021-06-10 13:04:55  2021      6   10    23        3    13  뉴발란스 992 그레이
# 365  2021-06-07 02:23:56  2021      6    7    23        0     2  뉴발란스 992 그레이
# 366  2021-05-04 09:56:52  2021      5    4    18        1     9  뉴발란스 992 그레이
# 367  2021-03-29 10:10:27  2021      3   29    13        0    10  뉴발란스 992 그레이
# 368  2021-03-29 10:10:17  2021      3   29    13        0    10  뉴발란스 992 그레이
#
#     brand product_type color  size
# 0    뉴발란스     뉴발란스 992   그레이   265
# 1    뉴발란스     뉴발란스 992   그레이   270
# 2    뉴발란스     뉴발란스 992   그레이   280
# 3    뉴발란스     뉴발란스 992   그레이   265
# 4    뉴발란스     뉴발란스 992   그레이   285
# ..    ...          ...   ...   ...
# 364  뉴발란스     뉴발란스 992   그레이   235
# 365  뉴발란스     뉴발란스 992   그레이   270
# 366  뉴발란스     뉴발란스 992   그레이   230
# 367  뉴발란스     뉴발란스 992   그레이   270
# 368  뉴발란스     뉴발란스 992   그레이   270
#
# [335 rows x 22 columns]

# %% [markdown]
# ## location 컬럼

# %%
newbal_gray['location'].head()
# Out:
# 0     서울특별시 강서구 발산제1동
# 1     서울특별시 강서구 발산제1동
# 2       인천광역시 서구 청라3동
# 3          경기도 부천시 상동
# 4    경상남도 창원시 성산구 상남동
# Name: location, dtype: object

# %%
def loc_split(x):
    return x.split()

# %%
newbal_gray['location'][0].split()
# Out:
# ['서울특별시', '강서구', '발산제1동']

# %%
newbal_gray['location'].apply(loc_split)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-196-759c70ea9b8d> in <module>
# ----> 1 newbal_gray['location'].apply(loc_split)
#
# ~/opt/anaconda3/envs/test/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-194-0570edf46994> in loc_split(x)
#       1 def loc_split(x):
# ----> 2     return x.split()
#
# AttributeError: 'float' object has no attribute 'split'

# %%
if test[0][-1] == '시':
    print(test[0])
# Out:
# 서울특별시

# %%
newbal_gray
# Out:
#         ad           location                          name  num_comment  \
# 0    False    서울특별시 강서구 발산제1동        265) 뉴발란스 992 그레이 팝니다.            0
# 1    False    서울특별시 강서구 발산제1동  270) 뉴발란스 992 그레이 팝니다(박스구겨짐)            0
# 2    False      인천광역시 서구 청라3동            [280] 뉴발란스 992 그레이            0
# 3    False         경기도 부천시 상동              뉴발란스 992 그레이 265            0
# 4    False   경상남도 창원시 성산구 상남동            [285] 뉴발란스 992 그레이            0
# ..     ...                ...                           ...          ...
# 364  False     서울특별시 송파구 풍납2동            [235] 뉴발란스 992 그레이            0
# 365  False  경기도 고양시 일산서구 주엽2동            [270] 뉴발란스 992 그레이            0
# 366  False        경기도 군포시 금정동            [230] 뉴발란스 992 그레이            0
# 367  False   서울특별시 서대문구 홍제제2동              뉴발란스 992 그레이 270            0
# 368  False   서울특별시 서대문구 홍제제2동              뉴발란스 992 그레이 270            0
#
#      num_faved   price  status       uid  used  bun_pay_filter_enabled  \
# 0            9  410000       0   1585398     2                    True
# 1            3  390000       0   1585398     2                    True
# 2            0  380000       0   3756852     2                   False
# 3            0  400000       0  75182195     2                   False
# 4            0  345000       0   9987908     2                   False
# ..         ...     ...     ...       ...   ...                     ...
# 364          0  300000       3   5619804     2                    True
# 365          0  390000       3   2477372     2                   False
# 366          5  360000       3   7623840     2                   False
# 367          2  420000       3  12944178    13                   False
# 368          1  420000       3  12944178     2                   False
#
#                 datetime  year  month  day  week  weekday  hour         pname  \
# 0    2021-11-11 09:24:24  2021     11   11    45        3     9  뉴발란스 992 그레이
# 1    2021-11-11 09:24:24  2021     11   11    45        3     9  뉴발란스 992 그레이
# 2    2021-11-11 08:31:40  2021     11   11    45        3     8  뉴발란스 992 그레이
# 3    2021-11-11 08:04:30  2021     11   11    45        3     8  뉴발란스 992 그레이
# 4    2021-11-11 07:55:01  2021     11   11    45        3     7  뉴발란스 992 그레이
# ..                   ...   ...    ...  ...   ...      ...   ...           ...
# 364  2021-06-10 13:04:55  2021      6   10    23        3    13  뉴발란스 992 그레이
# 365  2021-06-07 02:23:56  2021      6    7    23        0     2  뉴발란스 992 그레이
# 366  2021-05-04 09:56:52  2021      5    4    18        1     9  뉴발란스 992 그레이
# 367  2021-03-29 10:10:27  2021      3   29    13        0    10  뉴발란스 992 그레이
# 368  2021-03-29 10:10:17  2021      3   29    13        0    10  뉴발란스 992 그레이
#
#     brand product_type color  size
# 0    뉴발란스     뉴발란스 992   그레이   265
# 1    뉴발란스     뉴발란스 992   그레이   270
# 2    뉴발란스     뉴발란스 992   그레이   280
# 3    뉴발란스     뉴발란스 992   그레이   265
# 4    뉴발란스     뉴발란스 992   그레이   285
# ..    ...          ...   ...   ...
# 364  뉴발란스     뉴발란스 992   그레이   235
# 365  뉴발란스     뉴발란스 992   그레이   270
# 366  뉴발란스     뉴발란스 992   그레이   230
# 367  뉴발란스     뉴발란스 992   그레이   270
# 368  뉴발란스     뉴발란스 992   그레이   270
#
# [335 rows x 22 columns]
