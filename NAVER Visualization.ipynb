# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings(action='ignore')

from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

pd.options.display.max_rows=100
pd.options.display.max_columns=100

# 폰트깨짐 해결하기
## unicode minus를 사용하지 않기 위한 설정 (minus 깨짐현상 방지)
plt.rcParams['axes.unicode_minus'] = False
## 나눔고딕 설정
plt.rcParams['font.family'] = 'NanumGothic'
## 폰트 크기 조절
plt.rcParams['font.size'] = 23

# %%
trend = pd.read_csv('./data/NAVER-trend/NAVER_trend.csv')
shop = pd.read_csv('./data/NAVER-shopping/NAVER_shop.csv')

# %%
trend
# Out:
#              날짜  조던1 하이 다크모카  조던1 하이 스모크그레이  조던1 하이 하이퍼로얄  조던1 미드 그레이포크  \
# 0    2020-11-01      0.00000        7.14285           0.0             0
# 1    2020-11-02      0.00000        9.52380           0.0             0
# 2    2020-11-03      0.00000        5.95238           0.0             0
# 3    2020-11-04      8.33333        7.14285           0.0             0
# 4    2020-11-05      0.00000        0.00000           0.0             0
# ..          ...          ...            ...           ...           ...
# 373  2021-11-09      0.00000        0.00000           0.0             0
# 374  2021-11-10      0.00000        0.00000           0.0             0
# 375  2021-11-11      0.00000        0.00000           0.0             0
# 376  2021-11-12      0.00000        0.00000           0.0             0
# 377  2021-11-13      0.00000        0.00000           0.0             0
#
#      조던1 미드 스모크그레이  조던1 미드 울프그레이  조던1 미드 짐레드  조던1 로우 스타피쉬  조던1 로우 울프그레이  \
# ...

# %% [markdown]
# # Lineplot
# ## Time Series

# %%
import

# %%
trend['날짜'] = pd.to_datetime(trend['날짜'])
trend['날짜'][0].dt.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-711188dd22ad> in <module>
#       1 trend['날짜'] = pd.to_datetime(trend['날짜'])
# ----> 2 trend['날짜'][0].dt.month
#
# AttributeError: 'Timestamp' object has no attribute 'dt'

# %%
plt.figure(figsize=(10,10))
plt.title('조던 1', fontsize=15)
plt.grid()

trend['날짜'].values[0]
# Out:
# str

# %% [markdown]
# # Heatmap
# ## 제품 간 상관관계

# %%
corr = trend.corr()

plt.figure(figsize=(15,15))
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
# jordan_trend = trend[['조던1 하이 다크모카','조던1 로우 트레비스 스캇']]
jordan_trend = trend.iloc[:, 0:9]
corr_jordan = jordan_trend.corr()
corr_jordan
sns.heatmap(corr_jordan)
# Out:
# <AxesSubplot:>
